# %%
#Import libraries

from bs4 import BeautifulSoup
import requests
import smtplib
import time
import datetime
import csv
import pandas as pd

# Connect to the website

URL = 'https://www.amazon.com.mx/Talk-Data-Me-Scientist-Analyst/dp/B09W8XMRTR/ref=sr_1_33?__mk_es_MX=%C3%85M%C3%85%C5%BD%C3%95%C3%91&dib=eyJ2IjoiMSJ9.PxZ0e-8-_mkLjkKidMTHN0U2EZE-erNxVWpsJt7_80jzsFahALJedpqLOVNqJQiXG6qfjbHIjIu3kcTntjh_lpcuGgaf2ckhmozg90tNyiZulk2z3XJ1uGka1B2f4YfHF11bKrynrkmkzUBOnjOLiFMXBZxl86hljA7fJ-0NrU-V-Qb6YuzfwRntbTSdgo6-eLC9n9pCSodrP91mPdKNbbjY1m1-QByeegC-JddSJzIYZuYPdyI4j-eoolXRaAa6_LY0-Zl-PdsV6729N-tJaQMYCobJQBN_PSZvZUGxBd4.D9CLltISSqO_mKai4EfA9FerJxrBA5XDlDnEyrsRDnM&dib_tag=se&keywords=data+analyst+shirt&qid=1757726828&sr=8-33&ufe=app_do%3Aamzn1.fos.de93fa6a-174c-4df7-be7c-5bc8e9c5a71b'

headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:142.0) Gecko/20100101 Firefox/142.0", "Priority": "u=0, i"}

page = requests.get(URL, headers=headers)

Soup1 = BeautifulSoup(page.content, "html.parser")
# Soup1 takes all content from the static page.

Soup2 = BeautifulSoup(Soup1.prettify(), 'html.parser')
#Soup2 also takes all content from the static page but formats it a little better with prettify

title = Soup2.find(id='productTitle').get_text()
print(title)

# Find the span within Soup2
price = Soup2.find('span', class_='aok-offscreen').get_text()
print(price)
# Out:
#                   Talk Data To Me - Data Scientist Data Analyst T-shirt
#
#
#                   $405.47

# %%
# Let's clean it up a little bit.
title = title.strip()
price = price.strip()[1:]

print(title)
print(price)
type(price)
# Out:
# Talk Data To Me - Data Scientist Data Analyst T-shirt
# 405.47
# str

# %%
today = datetime.date.today()

print(today)
# Out:
# 2025-09-20

# %%
# Create csv

header = ['ProductName', 'Price', 'Date']
data = [title, price, today]

# with open('AmazonWebScraperDataset.csv', 'w', newline = '', encoding = 'UTF8' ) as f:
#    writer = csv.writer(f)
#    writer.writerow(header)
#    writer.writerow(data)

# %%
df = pd.read_csv(r'C:\Users\madys\AmazonWebScraperDataset.csv')
print(df)
# Out:
#                                          ProductName   Price        Date
# 0  Talk Data To Me - Data Scientist Data Analyst ...  405.47  2025-09-20
# 1  Talk Data To Me - Data Scientist Data Analyst ...  405.47  2025-09-20
# 2  Talk Data To Me - Data Scientist Data Analyst ...  405.47  2025-09-20
# 3  Talk Data To Me - Data Scientist Data Analyst ...  405.47  2025-09-20
# 4  Talk Data To Me - Data Scientist Data Analyst ...  405.47  2025-09-20
# 5  Talk Data To Me - Data Scientist Data Analyst ...  405.47  2025-09-20
# 6  Talk Data To Me - Data Scientist Data Analyst ...  405.47  2025-09-20
# 7  Talk Data To Me - Data Scientist Data Analyst ...  405.47  2025-09-20

# %%
# Apending data to the csv

with open('AmazonWebScraperDataset.csv', 'a+', newline = '', encoding = 'UTF8' ) as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %%
def check_price():
    URL = 'https://www.amazon.com.mx/Talk-Data-Me-Scientist-Analyst/dp/B09W8XMRTR/ref=sr_1_33?__mk_es_MX=%C3%85M%C3%85%C5%BD%C3%95%C3%91&dib=eyJ2IjoiMSJ9.PxZ0e-8-_mkLjkKidMTHN0U2EZE-erNxVWpsJt7_80jzsFahALJedpqLOVNqJQiXG6qfjbHIjIu3kcTntjh_lpcuGgaf2ckhmozg90tNyiZulk2z3XJ1uGka1B2f4YfHF11bKrynrkmkzUBOnjOLiFMXBZxl86hljA7fJ-0NrU-V-Qb6YuzfwRntbTSdgo6-eLC9n9pCSodrP91mPdKNbbjY1m1-QByeegC-JddSJzIYZuYPdyI4j-eoolXRaAa6_LY0-Zl-PdsV6729N-tJaQMYCobJQBN_PSZvZUGxBd4.D9CLltISSqO_mKai4EfA9FerJxrBA5XDlDnEyrsRDnM&dib_tag=se&keywords=data+analyst+shirt&qid=1757726828&sr=8-33&ufe=app_do%3Aamzn1.fos.de93fa6a-174c-4df7-be7c-5bc8e9c5a71b'

    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:142.0) Gecko/20100101 Firefox/142.0", "Priority": "u=0, i"}

    page = requests.get(URL, headers=headers)

    Soup1 = BeautifulSoup(page.content, "html.parser")

    Soup2 = BeautifulSoup(Soup1.prettify(), 'html.parser')
    
    title = Soup2.find(id='productTitle').get_text()

    price = Soup2.find('span', class_='aok-offscreen').get_text()

    # Let's clean it up a little bit.
    title = title.strip()
    price = price.strip()[1:]
    today = datetime.date.today()
    
    with open('AmazonWebScraperDataset.csv', 'a+', newline = '', encoding = 'UTF8' ) as f:
        writer = csv.writer(f)
        writer.writerow(data)

# %%
while(True):
    check_price()
    time.sleep(86400)
